# %%
import pandas as pd
df = pd.read_csv('heart_failure_clinical_records.csv')
print(df.head())
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  55.0        0                       748         0                 45
# 1  65.0        0                        56         0                 25
# 2  45.0        0                       582         1                 38
# 3  60.0        1                       754         1                 40
# 4  95.0        1                       582         0                 30
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    0  263358.03               1.3           137    1
# 1                    0  305000.00               5.0           130    1
# 2                    0  319000.00               0.9           140    0
# 3                    1  328000.00               1.2           126    1
# 4                    0  461000.00               2.0           132    1
#
#    smoking  time  DEATH_EVENT
# 0        1    88            0
# 1        0   207            0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

df = pd.read_csv('heart_failure_clinical_records.csv')

fig, ax = plt.subplots(figsize=(12, 6))

sns.histplot(data=df, x='age', bins=30, kde=True, color='purple')

plt.title('Age Histogram')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('heart_failure_clinical_records.csv')

x_axis = ['anaemia', 'creatinine_phosphokinase', 'diabetes', 'ejection_fraction', 
          'high_blood_pressure', 'platelets', 'serum_creatinine', 'serum_sodium']
plt.xticks(rotation=90)
y_axis = np.random.rand(8)

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'tab:orange']
widths = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
edgecolors = ['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black']

plt.bar(x_axis, y_axis, color=colors, width=widths, edgecolor=edgecolors)
plt.xlabel('Problems')
plt.ylabel('Values')
plt.title('Causes of Death')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()

ax.bar(age, sex, color='r', label='Males', width=2.5)
ax.bar(age, smoking, bottom=sex, color='b', label='Smoking rate', width=2.5)
ax.bar(age, time, bottom=sex+smoking, color='y', label='Minmum time', width=2.5)
ax.bar(age, DEATH_EVENT, bottom=sex+smoking+time, color='g', label='Death', width=2.5)

ax.set_title('Death Rate')
ax.set_xlabel('Age')
ax.set_ylabel('Percentage')
ax.set_xticks(age)
ax.legend()

plt.show()
